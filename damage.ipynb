# %%
# import libaries
import pandas as pd
import numpy as np
from scipy import stats

# %%
df = pd.read_excel('Scenario Anonymised v2.xlsx')

# %%
df.head(10)
# Out:
#               Flight Phase  Engine Serial Number Operator  Time / seconds  \
# 0  FlightPhaseEnum.taxiout                 11101      ABC        0.000000
# 1  FlightPhaseEnum.taxiout                 11101      ABC      944.000000
# 2  FlightPhaseEnum.takeoff                 11101      ABC      949.000000
# 3  FlightPhaseEnum.takeoff                 11101      ABC      973.776886
# 4  FlightPhaseEnum.takeoff                 11101      ABC      980.000000
# 5  FlightPhaseEnum.takeoff                 11101      ABC      996.001000
# 6  FlightPhaseEnum.takeoff                 11101      ABC     1108.000000
# 7    FlightPhaseEnum.climb                 11101      ABC     1113.000000
# 8    FlightPhaseEnum.climb                 11101      ABC     1270.000000
# 9    FlightPhaseEnum.climb                 11101      ABC     1478.000000
#
#    Temperature / Degrees  Predicted Part Damage  / mm  \
# 0             727.190125                          NaN
# 1             727.190125                          NaN
# 2             916.815519                          NaN
# 3             921.807580                          NaN
# 4             924.630174                          NaN
# 5             935.805692                          NaN
# 6             935.805692                          NaN
# 7             882.757830                     0.003407
# 8             902.854711                          NaN
# 9             909.088819                          NaN
#
#    Actual Part Damage / mm  \
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# 5                      NaN
# 6                      NaN
# 7                 0.003507
# 8                      NaN
# 9                      NaN
#
#    Instructions:\nYou’ve been asked to implement the following engineering equation to determine the damage to a turbine blade during each flight from Engine Health Monitoring data. Please develop code to show how you might implement this and what your considerations might be in dealing with data:\n\nDamage = OPERATOR_FACTOR x 1.2E-11 x AVERAGE_TEMP_FOR_CLIMB_PHASE^2.88\n\nOperator factor - ABC = 1, DEF = 1.1\n\n1% Chance of data corruption\n\nPart Damage validation data is provided\n\nTemperature has 1% measurement uncertainty
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN

# %%
# select all columns except last three as there are not input features of the damage equation
df = df.iloc[: , :-3]

# %%
df
# Out:
#                Flight Phase  Engine Serial Number Operator  Time / seconds  \
# 0   FlightPhaseEnum.taxiout                 11101      ABC        0.000000
# 1   FlightPhaseEnum.taxiout                 11101      ABC      944.000000
# 2   FlightPhaseEnum.takeoff                 11101      ABC      949.000000
# 3   FlightPhaseEnum.takeoff                 11101      ABC      973.776886
# 4   FlightPhaseEnum.takeoff                 11101      ABC      980.000000
# ..                      ...                   ...      ...             ...
# 90    FlightPhaseEnum.climb                 11105      ABC     2161.000000
# 91    FlightPhaseEnum.climb                 11105      ABC     2507.551163
# 92   FlightPhaseEnum.cruise                 11105      ABC     2512.551163
# 93   FlightPhaseEnum.cruise                 11105      ABC     8276.000000
# 94   FlightPhaseEnum.cruise                 11105      ABC     8368.000000
#
#     Temperature / Degrees
# 0              727.190125
# 1              727.190125
# 2              916.815519
# 3              921.807580
# 4              924.630174
# ..                    ...
# 90             818.224388
# 91             814.897915
# 92             771.389284
# 93             771.346432
# 94             771.346432
#
# [95 rows x 5 columns]

# %%
cols = df.select_dtypes('number').columns  # limits to a (float), b (int) and e (timedelta)
df_sub = df.loc[:, cols]

# %%
 # drop rows with nan values
df.dropna(subset=cols, inplace=True)

# %%
df
# Out:
#                Flight Phase  Engine Serial Number Operator  Time / seconds  \
# 0   FlightPhaseEnum.taxiout                 11101      ABC        0.000000
# 1   FlightPhaseEnum.taxiout                 11101      ABC      944.000000
# 2   FlightPhaseEnum.takeoff                 11101      ABC      949.000000
# 3   FlightPhaseEnum.takeoff                 11101      ABC      973.776886
# 4   FlightPhaseEnum.takeoff                 11101      ABC      980.000000
# ..                      ...                   ...      ...             ...
# 90    FlightPhaseEnum.climb                 11105      ABC     2161.000000
# 91    FlightPhaseEnum.climb                 11105      ABC     2507.551163
# 92   FlightPhaseEnum.cruise                 11105      ABC     2512.551163
# 93   FlightPhaseEnum.cruise                 11105      ABC     8276.000000
# 94   FlightPhaseEnum.cruise                 11105      ABC     8368.000000
#
#     Temperature / Degrees
# 0              727.190125
# 1              727.190125
# 2              916.815519
# 3              921.807580
# 4              924.630174
# ..                    ...
# 90             818.224388
# 91             814.897915
# 92             771.389284
# 93             771.346432
# 94             771.346432
#
# [94 rows x 5 columns]

# %%
# group the categorical features to aggregate the mean of numerical features
df = df.groupby(['Flight Phase', 'Engine Serial Number','Operator']).agg({'Temperature / Degrees': ['mean'],'Time / seconds': ['mean']})

# %%
# create new columns of average temperature and average time of flight phase
df.columns = ['average_temp','average_flight_phase_time']
df = df.reset_index()
print(df)
# Out:
#                Flight Phase  Engine Serial Number Operator  average_temp  \
# 0     FlightPhaseEnum.climb                 11101      ABC    870.777901
# 1     FlightPhaseEnum.climb                 11102      DEF    875.077487
# 2     FlightPhaseEnum.climb                 11103      ABC    875.566523
# 3     FlightPhaseEnum.climb                 11104      DEF    851.827002
# 4     FlightPhaseEnum.climb                 11105      ABC    814.389669
# 5    FlightPhaseEnum.cruise                 11101      ABC    789.233853
# 6    FlightPhaseEnum.cruise                 11102      DEF    823.374563
# 7    FlightPhaseEnum.cruise                 11103      ABC    794.542207
# 8    FlightPhaseEnum.cruise                 11104      DEF    801.364220
# 9    FlightPhaseEnum.cruise                 11105      ABC    771.360716
# 10  FlightPhaseEnum.takeoff                 11101      ABC    926.972932
# 11  FlightPhaseEnum.takeoff                 11102      DEF    937.350926
# 12  FlightPhaseEnum.takeoff                 11103      ABC    898.043377
# 13  FlightPhaseEnum.takeoff                 11104      DEF    835.675847
# 14  FlightPhaseEnum.takeoff                 11105      ABC    824.760254
# 15  FlightPhaseEnum.taxiout                 11101      ABC    727.190125
# 16  FlightPhaseEnum.taxiout                 11102      DEF    736.910918
# 17  FlightPhaseEnum.taxiout                 11103      ABC    729.184132
# 18  FlightPhaseEnum.taxiout                 11104      DEF    715.973825
# 19  FlightPhaseEnum.taxiout                 11105      ABC    719.712592
#
#     average_flight_phase_time
# 0                 1909.954955
# 1                 1506.475399
# 2                 1320.418664
# 3                 2776.718405
# 4                 1717.394574
# 5                17103.727928
# 6                11675.696104
# 7                11489.942922
# 8                 9649.116412
# 9                 6385.517054
# 10                1001.355577
# 11                 860.222140
# 12                 669.286598
# 13                2020.964233
# 14                1013.046539
# 15                 472.000000
# 16                 400.500000
# 17                 300.000000
# 18                 991.000000
# 19                 486.000000

# %%
def actual_part_damage(df):
   AVERAGE_TEMP_FOR_CLIMB_PHASE = df['average_temp']
   OPERATOR_FACTOR = {'ABC':1,'DEF':1.1}
   df['Op_factor'] = df['Operator'].map(OPERATOR_FACTOR)
   damage = df['Op_factor'] * 1.2e-11 * AVERAGE_TEMP_FOR_CLIMB_PHASE **2.88
   predicted_damage = damage - 1e-04

   df['actual_part_damage'] = damage
   df['predicted_part_damage'] = predicted_damage
   return df

# %%
# calling the function
df = actual_part_damage(df)

# %%
df
# Out:
#                Flight Phase  Engine Serial Number Operator  average_temp  \
# 0     FlightPhaseEnum.climb                 11101      ABC    870.777901
# 1     FlightPhaseEnum.climb                 11102      DEF    875.077487
# 2     FlightPhaseEnum.climb                 11103      ABC    875.566523
# 3     FlightPhaseEnum.climb                 11104      DEF    851.827002
# 4     FlightPhaseEnum.climb                 11105      ABC    814.389669
# 5    FlightPhaseEnum.cruise                 11101      ABC    789.233853
# 6    FlightPhaseEnum.cruise                 11102      DEF    823.374563
# 7    FlightPhaseEnum.cruise                 11103      ABC    794.542207
# 8    FlightPhaseEnum.cruise                 11104      DEF    801.364220
# 9    FlightPhaseEnum.cruise                 11105      ABC    771.360716
# 10  FlightPhaseEnum.takeoff                 11101      ABC    926.972932
# 11  FlightPhaseEnum.takeoff                 11102      DEF    937.350926
# 12  FlightPhaseEnum.takeoff                 11103      ABC    898.043377
# 13  FlightPhaseEnum.takeoff                 11104      DEF    835.675847
# 14  FlightPhaseEnum.takeoff                 11105      ABC    824.760254
# 15  FlightPhaseEnum.taxiout                 11101      ABC    727.190125
# 16  FlightPhaseEnum.taxiout                 11102      DEF    736.910918
# 17  FlightPhaseEnum.taxiout                 11103      ABC    729.184132
# 18  FlightPhaseEnum.taxiout                 11104      DEF    715.973825
# 19  FlightPhaseEnum.taxiout                 11105      ABC    719.712592
#
#     average_flight_phase_time  Op_factor    damage  actual_part_damage  \
# 0                 1909.954955        1.0  0.003517            0.003517
# 1                 1506.475399        1.1  0.003923            0.003923
# 2                 1320.418664        1.0  0.003573            0.003573
# 3                 2776.718405        1.1  0.003631            0.003631
# 4                 1717.394574        1.0  0.002900            0.002900
# 5                17103.727928        1.0  0.002649            0.002649
# 6                11675.696104        1.1  0.003292            0.003292
# 7                11489.942922        1.0  0.002701            0.002701
# 8                 9649.116412        1.1  0.003045            0.003045
# 9                 6385.517054        1.0  0.002480            0.002480
# 10                1001.355577        1.0  0.004211            0.004211
# 11                 860.222140        1.1  0.004782            0.004782
# 12                 669.286598        1.0  0.003843            0.003843
# 13                2020.964233        1.1  0.003436            0.003436
# 14                1013.046539        1.0  0.003007            0.003007
# 15                 472.000000        1.0  0.002093            0.002093
# 16                 400.500000        1.1  0.002392            0.002392
# 17                 300.000000        1.0  0.002109            0.002109
# 18                 991.000000        1.1  0.002201            0.002201
# 19                 486.000000        1.0  0.002031            0.002031
#
#     predicted_part_damage
# 0                0.003417
# 1                0.003823
# 2                0.003473
# 3                0.003531
# 4                0.002800
# 5                0.002549
# 6                0.003192
# 7                0.002601
# 8                0.002945
# 9                0.002380
# 10               0.004111
# 11               0.004682
# 12               0.003743
# 13               0.003336
# 14               0.002907
# 15               0.001993
# 16               0.002292
# 17               0.002009
# 18               0.002101
# 19               0.001931

# %%
df.to_csv('damage_actual_predicted.csv')
